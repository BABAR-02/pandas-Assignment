# %% [markdown]
# *Pandas*

# %% [markdown]
# Pandas is a Python library for data assessment and control. It is one of the most notable libraries for data science and man-made intelligence, and is used by data analysts and examiners from one side of the planet to the next.
#
# Pandas gives different components that make it ideal for data science, including:
#
# DataFrames: DataFrames are the middle data structure in Pandas. They are two-layered tables that can store different data types, including numerics, strings, and obvious data. DataFrames are very useful for data assessment and control.
#
# Data cleaning and preprocessing: Pandas gives various instruments to data cleaning and preprocessing, for instance, killing missing characteristics, dealing with special cases, and encoding obvious data. These endeavors are crucial for preparing data for man-made intelligence models.
#
# Feature planning: Pandas can be used to make new components from existing data. This collaboration is known as component planning, and it might be used to deal with the introduction of man-made intelligence models.
#
# Data portrayal: Pandas furthermore gives gadgets to data insight, for instance, histograms, line plots, and scatter plots. Data discernment is huge for understanding and unraveling data, and it can in like manner be used to recognize models and examples that may be elusive in unrefined data.
#
# Despite these overall components, Pandas in like manner gives different unequivocal features that are useful for artificial intelligence, for instance,
#
# Cross-endorsement: Pandas can be used to execute cross-endorsement, which is a technique for surveying the show of simulated intelligence models on hid data.
#
# Model evaluation: Pandas can be used to figure out various estimations for surveying the show of simulated intelligence models, similar to precision, exactness, audit, and F1 score.

# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Pandas DataFrames seem to be two-layered tables or accounting sheets with checked hatchets for the two lines and sections. These plans offer generous capacities with regards to data evaluation and change, transforming into a staple in the spaces of data science

# %%
import pandas as pd

# Create a DataFrame from a list of lists
data = [['Babar', 23], ['Ahmed', 20], ['Abdul Ahad', 18]]
df = pd.DataFrame(data, columns=['name', 'age'])

# Print the DataFrame
print(df)
# Out:
#          name  age
# 0       Babar   23
# 1       Ahmed   20
# 2  Abdul Ahad   18

# %% [markdown]
# DataFrames can moreover be produced using word references, NumPy bunches, and different data sources.
#
# At the point when a data frame is made, it might be controlled in different ways. For example, you can:
#
# Select unequivocal lines and segments from the DataFrame
# Perform assessments on the data in the DataFrame
# Add, dispense with, and adjust segments in the DataFrame
# Sort and assemble the data in the DataFrame
# Union and join different DataFrames
# DataFrames are furthermore uncommonly useful for data portrayal. You can use Pandas to make various outlines and plots from your data, for instance, histograms, line plots, and disseminate plots.

# %%
# Select the first two rows of the DataFrame
df.head(1)
# Out:
#     name  age
# 0  Babar   23

# %%
df.tail()
# Out:
#          name  age
# 0       Babar   23
# 1       Ahmed   20
# 2  Abdul Ahad   18

# %%
# Select the "name" column from the DataFrame
df["name"]
# Out:
# 0         Babar
# 1         Ahmed
# 2    Abdul Ahad
# Name: name, dtype: object

# %%
# Calculate the average age of the people in the DataFrame
df["age"].mean()
# Out:
# 20.333333333333332

# %%
# Calculate the difference between the oldest and youngest person in the DataFrame
df["age"].max() - df["age"].min()
# Out:
# 5

# %%
df["age"].max()
# Out:
# 23

# %% [markdown]
# *We can read this CSV dataset into a Pandas DataFrame using the following code:*

# %%
import pandas as pd

# Read the CSV dataset into a DataFrame
df = pd.read_csv('titanic.csv')

# Print the DataFrame
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# Calculate the average age of the people in the DataFrame
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
df["Age"].median()
# Out:
# 28.0

# %%
df["Age"].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df["Age"].std()
# Out:
# 14.526497332334042

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].min()
# Out:
# 0.42

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# Create a histogram of the ages in the DataFrame
plt.hist(df["Age"])
plt.xlabel("Age")
plt.ylabel("Number of people")
plt.title("Age distribution")
plt.show()

# %%
# Filter the DataFrame to only include people who are over 30 years old
df_filtered = df[df["Age"] > 30]
df_filtered
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# *Here are a few extra ways to work with Pandas DataFrames and CSV records:*
#
# Utilize the read_csv() capability to peruse a CSV record into a DataFrame.
# Utilize the to_csv() capability to trade a DataFrame to a CSV document.
# Utilize the head() and tail() capabilities to see the first and last couple of lines of a DataFrame.
# Utilize the data() capability to get data about a DataFrame, for example, the quantity of lines and segments, the information types, and the memory utilization.
# Utilize the depict() capability to get outline insights for a DataFrame, like the mean, middle, standard deviation, and least and greatest qualities.
# Utilize the question() capability to channel a DataFrame in view of a Boolean articulation.
# Utilize the sort_values() capability to sort the lines in a DataFrame by at least one segment.
# Utilize the drop() capability to eliminate lines and segments from a DataFrame.
# Utilize the rename() capability to rename sections in a DataFrame.
# Utilize the consolidation() capability to join at least two DataFrames together

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Data cleaning and preprocessing:

# %% [markdown]
# Pandas is areas of strength for a library for data control and assessment. It gives a considerable number of gadgets for data cleaning and preprocessing, which are essential stages in preparing data for man-made intelligence models. Here is a breakdown of a couple of typical data cleaning and preprocessing endeavors using Pandas:
#
# Dealing with Missing Characteristics:
# Missing characteristics, regularly tended to as NaN (Not a Number) or invalid, can basically impact the show and accuracy of simulated intelligence models. Pandas gives capacities to recognize and manage missing characteristics:
#
# *isnull() and notnull():* These capacities check for missing characteristics in a DataFrame or Series.
#
# *dropna():* This capacity wipes out lines or segments containing missing characteristics considering decided measures.
#
# *fillna():* This capacity replaces missing characteristics with decided values, similar to the mean, center, or a steady worth.

# %%
import pandas as pd

data = {'Age': [25, 30, None, 40], 'Salary': [50000, None, 60000, 70000]}
df = pd.DataFrame(data)

missing_values = df.isnull()
print(missing_values)
# Out:
#      Age  Salary
# 0  False   False
# 1  False    True
# 2   True   False
# 3  False   False

# %%
df=pd.read_csv('titanic.csv')
missing_values = df.isnull()
missing_values
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df=pd.read_csv('employees.csv')
missing_values = df.isnull()
missing_values
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# ...

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("employees.csv")

# creating bool series False for NaN values
bool_series = pd.notnull(data["Gender"])

# displayed data only with team = NaN
data[bool_series]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df=pd.read_csv('employees.csv')
missing_values = df.isnull().sum()
missing_values
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df=pd.read_csv('employees.csv')
notmissing_values = df.notnull().sum()
notmissing_values
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %% [markdown]
# dropna(): This function removes rows or columns containing missing values based on specified criteria.
# dropna(): This function removes rows or columns containing missing values based on specified criteria.
#
# axis='index' removes rows with missing values.
#
# axis='columns' removes columns with missing values.
#
# how='any' removes a row or column if any value is missing.
#
# how='all' removes a row or column only if all values are missing.
#
# thresh=n removes a row or column if it has less than n non-missing values.
#
# subset=[list of columns] restricts the check for missing values to specific columns.
#
# axis='index': Drops rows that contain missing values. This is the default behavior.

# %%
df = pd.read_csv('employees.csv')

print("======= before  =========")
print(df.shape) 
print(df.isnull().sum()) 

# Drop rows with any missing values
df.dropna(axis='index', inplace=True)
print("======= After  =========")
# Check if there are still missing values 
print(df.isnull().sum())
# Out:
# ======= before  =========
# (1000, 8)
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64
# ======= After  =========
# First Name           0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('employees.csv')
# Print original DataFrame shape

print("======= before  =========")
print(df.shape) 
print(df.isnull().sum())

print("======= After  =========")
# Drop columns with any missing values
df.dropna(axis='columns', inplace=True)
# Print new DataFrame shape  
print(df.shape)

print(df.isnull().sum())
# Out:
# ======= before  =========
# (1000, 8)
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64
# ======= After  =========
# (1000, 4)
# Start Date         0
# Last Login Time    0
# Salary             0
# Bonus %            0
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('employees.csv')

print("======= BEFORE ========")
print(df.shape)
print(df.isnull().sum()) 

# Drop columns with any missing values
df.dropna(axis='columns', how='any', inplace=True)

print("\n======= AFTER ========")
print(df.shape) 
print(df.isnull().sum())
# Out:
# ======= BEFORE ========
# (1000, 8)
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64
#
# ======= AFTER ========
# (1000, 4)
# Start Date         0
# Last Login Time    0
# Salary             0
# Bonus %            0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv('employees.csv')
print("======= BEFORE =======")


print(df.shape)
print(df.isnull().sum())

print("\n======= AFTER =======")

df.dropna(axis='columns', how='all', inplace=True) 

print(df.shape)
print(df.isnull().sum())
# Out:
# ======= BEFORE =======
# (1000, 8)
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64
#
# ======= AFTER =======
# (1000, 8)
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('employees.csv')

print("======= BEFORE =======")  
print(df.shape)
print(df.isnull().sum())

# Drop columns with less than 3 non-NaN values
df.dropna(axis='columns', thresh=100, inplace=True)

print("\n======= AFTER =======")
print(df.shape) 
print(df.isnull().sum())
# Out:
# ======= BEFORE =======
# (1000, 8)
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64
#
# ======= AFTER =======
# (1000, 8)
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('employees.csv')

print("======= BEFORE =======")
print(df.shape)
print(df.isnull().sum())

# Only drop rows with missing values in columns B and C 
df.dropna(axis='index', subset=['First Name','Gender'], inplace=True)

print("\n======= AFTER =======")
print(df.shape)
print(df.isnull().sum())
# Out:
# ======= BEFORE =======
# (1000, 8)
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64
#
# ======= AFTER =======
# (795, 8)
# First Name            0
# Gender                0
# Start Date            0
# Last Login Time       0
# Salary                0
# Bonus %               0
# Senior Management     0
# Team                 31
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('employees.csv')

print("======= BEFORE =======")
print(df.shape)
print(df.isnull().sum())

# Interpolate missing values  
df = df['Salary'].interpolate()

print("\n======= AFTER =======")
print(df.shape)  
print(df.isnull().sum())
df.info()
# Out:
# ======= BEFORE =======
# (1000, 8)
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64
#
# ======= AFTER =======
# (1000,)
# 0
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Salary
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   int64
# dtypes: int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# *Identifying and Handling Outliers:*

# %% [markdown]
# Anomalies are outrageous qualities that go astray fundamentally from the other information. They can slant the aftereffects of AI models. Pandas offers strategies to identify and address exceptions:
#
# depict(): This capability gives outline measurements, including quartiles, which can assist with distinguishing expected exceptions.
#
# boxplot(): Boxplots outwardly address the dispersion of information and feature exceptions.
#
# zscore(): This capability computes the z-score, a proportion of how far a worth is from the mean. Enormous z-scores might show anomalies.
#
# Exceptions can be taken care of by eliminating them, crediting them with less outrageous qualities, or utilizing vigorous models less delicate to anomalies.

# %%
pip install scipy
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd
import numpy as np
from scipy import stats

df = pd.read_csv('employees.csv')

print(df.describe()) 

# Create boxplots 
df.boxplot(column=['Salary', 'Bonus %'])

# Calculate z-scores
z = np.abs(stats.zscore(df))

# Filter outlier rows by z-score threshold
df = df[(z < 3).all(axis=1)]  

print(df.describe())
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\python learning\Pandas\pandas.ipynb Cell 48 line 1
#      <a href='vscode-notebook-cell:/d%3A/python%20learning/Pandas/pandas.ipynb#X66sZmlsZQ%3D%3D?line=9'>10</a> df.boxplot(column=['Salary', 'Bonus %'])
#      <a href='vscode-notebook-cell:/d%3A/python%20learning/Pandas/pandas.ipynb#X66sZmlsZQ%3D%3D?line=11'>12</a> # Calculate z-scores
# ---> <a href='vscode-notebook-cell:/d%3A/python%20learning/Pandas/pandas.ipynb#X66sZmlsZQ%3D%3D?line=12'>13</a> z = np.abs(stats.zscore(df))
# ...
